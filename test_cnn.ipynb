# %%
import numpy as np
from matplotlib import pyplot as plt
from cnn import preprocess_data, one_hot_encode

# %%
training = np.loadtxt("dataset/train.csv",
                 delimiter=",", dtype=str)
training_labels = training[1:, 0]
training_data = training[1:, 1:].astype(float) / 255

training_labels = one_hot_encode(training_labels)
training_data = preprocess_data(training_data)

display(training_labels.shape)
display(training_data.shape)
# Out:
# (38000, 10)
# (38000, 1, 28, 28)

# %%
plt.imshow(training_data[0, 0, :, :])
